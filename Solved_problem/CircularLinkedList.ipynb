# %%
class Node:
    def __init__(self,val=0,next=None):
        self.val=val
        self.next=next
class cll:
    def print(self,last):
        if last is None:
            print("List is empty")
            return
        temp = last.next   # first node
        while True:
            print(temp.val, end=" -> ")
            temp = temp.next
            if temp == last.next:
                print("\n")
                break
    def insert_at_Begning(self,last,val):
        if last==None:
            last=Node(val)
            last.next=last
        n=Node(val)
        n.next=last.next
        last.next=n

    def insert_at_end(self,last,val):
        if last==None:
            last=Node(val)
            last.next=last
        n=Node(val)
        n.next=last.next
        last.next=n
        last=n

    def insert_at_pos(self,last,val,pos):
        if last==None:
            last=Node(val)
            last.next=last
        n=Node(val)
        count=1
        temp=last.next
        while temp:
            if count==pos:
                n=Node(val)
                n.next=temp.next
                temp.next=n
            count=count+1
            temp=temp.next
            if temp==last.next:
                return
            
    def delete_first(self,last):
        if last==None:
            return
        last.next=last.next.next
    def delete_last(self,last):
        if last==None:
            return
        temp=last
        while temp:
            if temp.next==last:
                temp.next=last.next
                break
            temp=temp.next
    def delete_pos(self,last,pos):
        if last==None:
            return
        temp=last
        count=1
        while temp:
            if count==pos:
                temp.next=temp.next.next
            count=count+1
            temp=temp.next
            if temp==last.next:
                return

    




    def count(self,last):
        count=0
        temp=last.next
        while temp:
            temp=temp.next
            count=count+1
            if temp==last.next:
                break
        return count
    def search(self,last,val):
        temp=last.next
        while temp:
            temp=temp.next
            if val==temp.val:
                return temp.val
            if temp==last.next:
                break
        return -1






    
n1=Node(1)
n2=Node(2)
n3=Node(3)
n4=Node(4)

n1.next=n2
n2.next=n3
n3.next=n4
n4.next=n1 #circular linked list
l=cll()
l.print(n4)
l.insert_at_Begning(n4,8)
l.print(n4)
l.insert_at_end(n4,9)
l.print(n4.next)
l.insert_at_pos(n4.next,11,2)
l.print(n4.next)
l.delete_first(n4.next)

l.print(n4.next)
l.delete_last(n4.next)
l.delete_last(n4)
l.print(n4)
print(l.count(n4))
print(l.search(n4,2))
l.delete_pos(n4,2)
l.print(n4)
# Out:
# 1 -> 2 -> 3 -> 4 ->
#
# 8 -> 1 -> 2 -> 3 -> 4 ->
#
# 8 -> 1 -> 2 -> 3 -> 4 -> 9 ->
#
# 8 -> 1 -> 11 -> 2 -> 3 -> 4 -> 9 ->
#
# 1 -> 11 -> 2 -> 3 -> 4 -> 9 ->
#
# 1 -> 11 -> 2 -> 3 ->
#
# 4
# 2
# 1 -> 11 -> 2 -> 3 ->

# %% [markdown]
# 7️⃣ Delete Node by Value
#
# Input
#
# 1 -> 2 -> 3 -> 4 -> 5
#
# Delete 3
#
# Output
#
# 1 -> 2 -> 4 -> 5
# 🔟 Split Circular Linked List
#
# Input
#
# 1 -> 2 -> 3 -> 4 -> 5 -> 6
#
# Output
#
# List1: 1 -> 2 -> 3
# List2: 4 -> 5 -> 6
#
# Use slow and fast pointer.
#
# 1️⃣1️⃣ Josephus Problem (Very Famous)
#
# Input
#
# n = 5
# k = 2
#
# Output
#
# 3
#
# Explanation
# Every 2nd person eliminated.
#
# 1️⃣2️⃣ Detect Circular Linked List
#
# Input
#
# 1 -> 2 -> 3 -> 4 -> back to 2
#
# Output
#
# True
#
# Use Floyd Cycle Detection (slow fast pointer).
#
# ⭐ Most Important CLL Questions (Interview)
#
# Insert beginning
#
# Insert end
#
# Delete node
#
# Traverse circular list
#
# Split circular list
#
# Josephus problem
#
# Detect cycle
#
# ⭐ Important Traversal Trick
#
# Circular list traversal always like this:
#
# temp = start
#
# while True:
#     print(temp.data)
#     temp = temp.next
#
#     if temp == start:
#         break
#
# Because there is no None.
#
# 🚀 Best Practice Order
# 1 Traverse
# 2 Insert beginning
# 3 Insert end
# 4 Delete node
# 5 Count
# 6 Search
# 7 Split list
# 8 Josephus problem
