# %% [markdown]
# Pandas problem

# %% [markdown]
# Creating a Series

# %%
import pandas as pd
a=(1,2,3,4,5)#tuple
print("using tuple:\n",pd.Series(a))
b=[9,6,3,2]#list
print("using list\n",pd.Series(b))
c={1:"sanya",2:"Anmol"}
print("Using dict  :\n",pd.Series(c))
# Out:
# using tuple:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# using list
#  0    9
# 1    6
# 2    3
# 3    2
# dtype: int64
# Using dict  :
#  1    sanya
# 2    Anmol
# dtype: object

# %% [markdown]
# Series to List Conversion

# %%
a=[1,2,3,4]
s=pd.Series(a)
b=list(a)
print(b)
print(type(b))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %% [markdown]
# Series Arithmetic

# %%
a=pd.Series([2, 4, 6, 8, 10])
b=pd.Series([1, 3, 5, 7, 9])
print("Add :\n",a+b)
print("Subtract :\n",a-b)
print("Multiple :\n",a*b)
print("Divide :\n",a/b)
# Out:
# Add :
#  0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# Subtract :
#  0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
# Multiple :
#  0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64
# Divide :
#  0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.111111
# dtype: float64

# %% [markdown]
# Series Comparison

# %%
a=pd.Series([2, 4, 6, 8, 10])
b=pd.Series([1, 3, 5, 7, 10])
print("Equal:",a==b)
print("greter then :\n",a>b)
print("less then :\n",a<b)
print("greter then equal :\n",a>=b)
print("less then equal :\n",a<=b)
# Out:
# Equal: 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# greter then :
#  0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# less then :
#  0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# greter then equal :
#  0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool
# less then equal :
#  0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Dict to Series

# %%
dict={'a': 100, 'b': 200, 'c': 300, 'd': 400, 'e': 800}
se=pd.Series(dict)
se
# Out:
# a    100
# b    200
# c    300
# d    400
# e    800
# dtype: int64

# %% [markdown]
#  Array to Series

# %%
arr=[10,20,30, 40,50]
print(pd.Series(arr))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Change Series DataType

# %%
s=pd.Series([100,200,"Python",300.12,400])
print("Original Series :")
print(s)
print("Change the said data type to numeric")
c=pd.to_numeric(s,errors='coerce')
print(c)
# Out:
# Original Series :
# 0       100
# 1       200
# 2    Python
# 3    300.12
# 4       400
# dtype: object
# Change the said data type to numeric
# 0    100.00
# 1    200.00
# 2       NaN
# 3    300.12
# 4    400.00
# dtype: float64

# %% [markdown]
# DF Column to Series

# %%
data=pd.DataFrame({'col1':[1,2,3,4,7,11],'col2':[4,5,6,9,5,0],'col3':[7,5,8,12,1,11]})
print("Datafarme :\n",data)
print("1st column as series :\n")
print(pd.Series(data['col1']))
# Out:
# Datafarme :
#     col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
# 1st column as series :
#
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5    11
# Name: col1, dtype: int64

# %% [markdown]
# Series to Array

# %%
a=pd.Series([1,2,3,4])
print("Original series : \n")
print(a)
print("Series to Array \n")
arr=a.values
print(arr)
# Out:
# Original series :
#
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# Series to Array
#
# [1 2 3 4]

# %% [markdown]
# Flatten Series of Lists

# %%
A=pd.Series({0:['Red','Green','White'],1:['Red','Green'],2:['Yellow']})
print("Original Series :\n",A)
print("One Series ")
b=A.values
print(b)
# Out:
# Original Series :
#  0    [Red, Green, White]
# 1           [Red, Green]
# 2               [Yellow]
# dtype: object
# One Series
# [list(['Red', 'Green', 'White']) list(['Red', 'Green']) list(['Yellow'])]

# %% [markdown]
# # Pandas DataFrame

# %%
#Creating Data Frame with dict
import pandas as pd
dict={'Name':['Sanya','Anmol','Drishya','Neetu','Umesh','Manya'],
      'Age':[20,22,23,42,52,16],
      'Sex':['Female','Male','Female','Female','Male','Female']}
data_frame=pd.DataFrame(dict)
data_frame
# Out:
#       Name  Age     Sex
# 0    Sanya   20  Female
# 1    Anmol   22    Male
# 2  Drishya   23  Female
# 3    Neetu   42  Female
# 4    Umesh   52    Male
# 5    Manya   16  Female

# %%
# DataFrame with index lavel
import pandas as pd
dict={'Name':['Sanya','Anmol','Drishya','Neetu','Umesh','Manya'],
      'Age':[20,22,23,42,52,16],
      'Sex':['Female','Male','Female','Female','Male','Female']}
l=pd.Series(['a','b','c','d','e','f'])
data_frame=pd.DataFrame(dict,index=l)
data_frame
# Out:
#       Name  Age     Sex
# a    Sanya   20  Female
# b    Anmol   22    Male
# c  Drishya   23  Female
# d    Neetu   42  Female
# e    Umesh   52    Male
# f    Manya   16  Female

# %%
# Summary of dataframe
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Sex     6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 192.0+ bytes

# %%
 #Selecting the First 2 Rows
data_frame.iloc[:3]
# Out:
#       Name  Age     Sex
# a    Sanya   20  Female
# b    Anmol   22    Male
# c  Drishya   23  Female

# %%
#Selecting 'name' and sex Columns
#data_frame.Name
data_frame[["Name","Sex"]]
# Out:
#       Name     Sex
# a    Sanya  Female
# b    Anmol    Male
# c  Drishya  Female
# d    Neetu  Female
# e    Umesh    Male
# f    Manya  Female

# %%
#Selecting Specific Columns and Rows
data_frame.iloc[[1,2,3],[1,2]]
# Out:
#    Age     Sex
# b   22    Male
# c   23  Female
# d   42  Female

# %%
#Selecting Rows Where Age > 18
data_frame[data_frame['Age']>18]
# Out:
#       Name  Age     Sex
# a    Sanya   20  Female
# b    Anmol   22    Male
# c  Drishya   23  Female
# d    Neetu   42  Female
# e    Umesh   52    Male

# %%
#Counting Rows and Columns
c=data_frame.columns
i=data_frame.index
print("Number of columns :",len(c))
print("Number of  Rows :",len(i))
# Out:
# Number of columns : 3
# Number of  Rows : 6

# %%
mapping = {
    'Sanya':'study',
    'Anmol': 'job',
    'Umesh':'farmer'
}

data_frame['work'] = data_frame['Name'].map(mapping)
data_frame
# Out:
#       Name  Age     Sex    work
# a    Sanya   20  Female   study
# b    Anmol   22    Male     job
# c  Drishya   23  Female     NaN
# d    Neetu   42  Female     NaN
# e    Umesh   52    Male  farmer
# f    Manya   16  Female     NaN

# %%
#Selecting Rows with Missing Score
data_frame[data_frame['work'].isna()]
# Out:
#       Name  Age     Sex work
# c  Drishya   23  Female  NaN
# d    Neetu   42  Female  NaN
# f    Manya   16  Female  NaN

# %%
#Selecting Rows Where Score is Between 20 and 35
data_frame[data_frame['Age'].between(20,35) ]
# Out:
#       Name  Age     Sex   work
# a    Sanya   20  Female  study
# b    Anmol   22    Male    job
# c  Drishya   23  Female    NaN

# %%
# Selecting Rows with age < 25 and sex=female
data_frame[(data_frame['Age']<25) & (data_frame['Sex']=='Female')]
# Out:
#       Name  Age     Sex   work
# a    Sanya   20  Female  study
# c  Drishya   23  Female    NaN
# f    Manya   16  Female    NaN

# %%
# Changing the age in a Specific Row
data_frame.loc['d','Age']=45
data_frame
# Out:
#       Name  Age     Sex    work
# a    Sanya   20  Female   study
# b    Anmol   22    Male     job
# c  Drishya   23  Female     NaN
# d    Neetu   45  Female     NaN
# e    Umesh   52    Male  farmer
# f    Manya   16  Female     NaN

# %%
import pandas as pd
import numpy as np

exam_data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

labels = ['a','b','c','d','e','f','g','h','i','j']

df = pd.DataFrame(exam_data, index=labels)
print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#. Summing Examination Attempts
df['attempts'].sum()
# Out:
# np.int64(19)

# %%
#Calculating the Mean of Scores
df['score'].mean()
# Out:
# np.float64(13.5625)

# %%
# Appending and Deleting a New Row
mapping={'Name':"Suresh", 'score': 15.5, 'attempts': 1, 'qualify': "yes", 'label': "k"}
df.loc['k']=[1, 'Suresh', 'yes', 15.5]
df
# Out:
#         name   score attempts qualify
# a  Anastasia    12.5        1     yes
# b       Dima     9.0        3      no
# c  Katherine    16.5        2     yes
# d      James     NaN        3      no
# e      Emily     9.0        2      no
# f    Michael    20.0        3     yes
# g    Matthew    14.5        1     yes
# h      Laura     NaN        1      no
# i      Kevin     8.0        2      no
# j      Jonas    19.0        1     yes
# k          1  Suresh      yes    15.5

# %%
df=df.drop('k')
df
# Out:
#         name score attempts qualify
# a  Anastasia  12.5        1     yes
# b       Dima   9.0        3      no
# c  Katherine  16.5        2     yes
# d      James   NaN        3      no
# e      Emily   9.0        2      no
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# j      Jonas  19.0        1     yes

# %%
df.sort_values(by=['name','score'],ascending=[False,True])
# Out:
#         name score attempts qualify
# f    Michael  20.0        3     yes
# g    Matthew  14.5        1     yes
# h      Laura   NaN        1      no
# i      Kevin   8.0        2      no
# c  Katherine  16.5        2     yes
# j      Jonas  19.0        1     yes
# d      James   NaN        3      no
# e      Emily   9.0        2      no
# b       Dima   9.0        3      no
# a  Anastasia  12.5        1     yes

# %%
#Replacing Column Values (qualify)
df['qualify']=df['qualify'].map({'yes':True,'no':False})
df
# Out:
#         name score attempts  qualify
# a  Anastasia  12.5        1     True
# b       Dima   9.0        3    False
# c  Katherine  16.5        2     True
# d      James   NaN        3    False
# e      Emily   9.0        2    False
# f    Michael  20.0        3     True
# g    Matthew  14.5        1     True
# h      Laura   NaN        1    False
# i      Kevin   8.0        2    False
# j      Jonas  19.0        1     True

# %%
#Changing a Specific Name Value
#data_frame.loc['d','Age']=45
df.loc[df['name'] == 'James', 'name'] = 'suresh'
df
# Out:
#         name score attempts  qualify
# a  Anastasia  12.5        1     True
# b       Dima   9.0        3    False
# c  Katherine  16.5        2     True
# d     suresh   NaN        3    False
# e      Emily   9.0        2    False
# f    Michael  20.0        3     True
# g    Matthew  14.5        1     True
# h      Laura   NaN        1    False
# i      Kevin   8.0        2    False
# j      Jonas  19.0        1     True

# %%
# Deleting a Column from the DataFrame
df.drop('attempts',axis=1)
# Out:
#         name score  qualify
# a  Anastasia  12.5     True
# b       Dima   9.0    False
# c  Katherine  16.5     True
# d     suresh   NaN    False
# e      Emily   9.0    False
# f    Michael  20.0     True
# g    Matthew  14.5     True
# h      Laura   NaN    False
# i      Kevin   8.0    False
# j      Jonas  19.0     True

# %%
#Inserting a New Column
df.insert(3,'color',['red','blue,','green','red','blue','black','pink','grey','sunny','red'])
df
# Out:
#         name score attempts  color  qualify
# a  Anastasia  12.5        1    red     True
# b       Dima   9.0        3  blue,    False
# c  Katherine  16.5        2  green     True
# d     suresh   NaN        3    red    False
# e      Emily   9.0        2   blue    False
# f    Michael  20.0        3  black     True
# g    Matthew  14.5        1   pink     True
# h      Laura   NaN        1   grey    False
# i      Kevin   8.0        2  sunny    False
# j      Jonas  19.0        1    red     True

# %%
import pandas as pd

exam_data = [
    {'name':'Anastasia', 'score':12.5},
    {'name':'Dima','score':9},
    {'name':'Katherine','score':16.5}
]

df1 = pd.DataFrame(exam_data)
print(df)
# Out:
#         name score attempts  color  qualify
# a  Anastasia  12.5        1    red     True
# b       Dima   9.0        3  blue,    False
# c  Katherine  16.5        2  green     True
# d     suresh   NaN        3    red    False
# e      Emily   9.0        2   blue    False
# f    Michael  20.0        3  black     True
# g    Matthew  14.5        1   pink     True
# h      Laura   NaN        1   grey    False
# i      Kevin   8.0        2  sunny    False
# j      Jonas  19.0        1    red     True

# %%
#Iterating Over DataFrame Rows
for i in df1.values:
    print(i)
# Out:
# ['Anastasia' 12.5]
# ['Dima' 9.0]
# ['Katherine' 16.5]

# %%
#Getting List from Column Headers
df1.columns
# Out:
# Index(['name', 'score'], dtype='object')

# %%
#Renaming DataFrame Columns
df1.rename(columns={'name':'col1','score':'col2'})
# Out:
#         col1  col2
# 0  Anastasia  12.5
# 1       Dima   9.0
# 2  Katherine  16.5

# %%
#Selecting Rows Based on Column Values
print(df)
df[df['attempts']==3]
# Out:
#         name score attempts  color  qualify
# a  Anastasia  12.5        1    red     True
# b       Dima   9.0        3  blue,    False
# c  Katherine  16.5        2  green     True
# d     suresh   NaN        3    red    False
# e      Emily   9.0        2   blue    False
# f    Michael  20.0        3  black     True
# g    Matthew  14.5        1   pink     True
# h      Laura   NaN        1   grey    False
# i      Kevin   8.0        2  sunny    False
# j      Jonas  19.0        1    red     True
#       name score attempts  color  qualify
# b     Dima   9.0        3  blue,    False
# d   suresh   NaN        3    red    False
# f  Michael  20.0        3  black     True

# %%
#Changing the Order of DataFrame Columns

# %%
#Add One Row to a DataFrame
print("Original DataFrame :")
print(df)
print("after add New Columns :")
df.loc['5']=['sanya',45,4,'blue','True']
df
# Out:
# Original DataFrame :
#         name score attempts  color  qualify
# a  Anastasia  12.5        1    red     True
# b       Dima   9.0        3  blue,    False
# c  Katherine  16.5        2  green     True
# d     suresh   NaN        3    red    False
# e      Emily   9.0        2   blue    False
# f    Michael  20.0        3  black     True
# g    Matthew  14.5        1   pink     True
# h      Laura   NaN        1   grey    False
# i      Kevin   8.0        2  sunny    False
# j      Jonas  19.0        1    red     True
# after add New Columns :
#         name score attempts  color qualify
# a  Anastasia  12.5        1    red    True
# b       Dima   9.0        3  blue,   False
# c  Katherine  16.5        2  green    True
# d     suresh   NaN        3    red   False
# e      Emily   9.0        2   blue   False
# f    Michael  20.0        3  black    True
# g    Matthew  14.5        1   pink    True
# h      Laura   NaN        1   grey   False
# ...

# %%
#Color Wise Count
df.groupby(df['color']).size().reset_index(name="num of people")
# Out:
#    color  num of people
# 0  black              1
# 1   blue              2
# 2  blue,              1
# 3  green              1
# 4   grey              1
# 5   pink              1
# 6    red              3
# 7  sunny              1

# %%
#Select Row by Integer Index\
df[1:2]
# Out:
#    name score attempts  color qualify
# b  Dima   9.0        3  blue,   False

# %%
df.iloc[[2]]
# Out:
#         name score attempts  color qualify
# c  Katherine  16.5        2  green    True

# %%
m = {
    "Dima": "Engineer",
    "Katherine": "Doctor",
    "Suresh": "Farmer",
    "Emily": "Teacher",
    "Michael": "Designer",
    "Matthew": "Developer",
    "Laura": "Nurse",
    "Kevin": "Police Officer"
}
#df.insert(0, "col1", [100, 100], allow_duplicates=True)
#df.insert[2, "work" , ["Engineer", "Doctor", "Farmer", "Teacher", "Driver", "Chef", "Lawyer", "Nurse", "Designer", "Mechanic","Mechanic"], allow_duplicates=True]
#df["work"]= ["Engineer", "Doctor", "Farmer", "Teacher", "Driver", "Chef", "Lawyer", "Nurse", "Designer", "Mechanic", "Mechanic"]
df
df["work"]=df["name"].map(m)
df
# Out:
#         name score attempts  color qualify            work
# a  Anastasia  12.5        1    red    True             NaN
# b       Dima   9.0        3  blue,   False        Engineer
# c  Katherine  16.5        2  green    True          Doctor
# d     suresh   NaN        3    red   False             NaN
# e      Emily   9.0        2   blue   False         Teacher
# f    Michael  20.0        3  black    True        Designer
# g    Matthew  14.5        1   pink    True       Developer
# h      Laura   NaN        1   grey   False           Nurse
# i      Kevin   8.0        2  sunny   False  Police Officer
# j      Jonas  19.0        1    red    True             NaN
# 5      sanya    45        4   blue    True             NaN

# %%
#Count NaN Values
n=df.isna().sum()
print("Number of NaN values in one or more columns:")
print(n.count())
# Out:
# Number of NaN values in one or more columns:
# 6

# %%
# Replace NaN with Zeros
df.fillna(0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16224\1048911027.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0)
#         name  score  attempts  color qualify            work
# a  Anastasia   12.5         1    red    True               0
# b       Dima    9.0         3  blue,   False        Engineer
# c  Katherine   16.5         2  green    True          Doctor
# d     suresh    0.0         3    red   False               0
# e      Emily    9.0         2   blue   False         Teacher
# f    Michael   20.0         3  black    True        Designer
# g    Matthew   14.5         1   pink    True       Developer
# h      Laura    0.0         1   grey   False           Nurse
# i      Kevin    8.0         2  sunny   False  Police Officer
# ...

# %%
# Drop Rows from DataFrame
df.drop(['b','d'],axis=0)
#df.drop([1,2],axis=0)
# Out:
#         name score attempts  color qualify            work
# a  Anastasia  12.5        1    red    True             NaN
# c  Katherine  16.5        2  green    True          Doctor
# e      Emily   9.0        2   blue   False         Teacher
# f    Michael  20.0        3  black    True        Designer
# g    Matthew  14.5        1   pink    True       Developer
# h      Laura   NaN        1   grey   False           Nurse
# i      Kevin   8.0        2  sunny   False  Police Officer
# j      Jonas  19.0        1    red    True             NaN
# 5      sanya    45        4   blue    True             NaN

# %%
import pandas as pd

# First Series
s1 = pd.Series([100, 200, 'python', 300.12, 400])

# Second Series
s2 = pd.Series([10, 20, 'php', 30.12, 40])

print(s1)
print()
print(s2)
com=pd.DataFrame(s1)
com[1]=s2
com
# Out:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400
# dtype: object
#
# 0       10
# 1       20
# 2      php
# 3    30.12
# 4       40
# dtype: object
#         0      1
# 0     100     10
# 1     200     20
# 2  python    php
# 3  300.12  30.12
# 4     400     40

# %%
com=pd.concat([s1,s2],axis=1)
com
# Out:
#         0      1
# 0     100     10
# 1     200     20
# 2  python    php
# 3  300.12  30.12
# 4     400     40
