# %% [markdown]
# Doubly Linked List Problems with soluthion

# %% [markdown]
# Traverse Doubly Linked List (Forward)
#
# Input list
#
# None <- 1 <-> 2 <-> 3 <-> 4 -> None
#
# Expected Output
#
# 1 -> 2 -> 3 -> 4 -> None
# 2️⃣ Traverse Doubly Linked List (Backward)
#
# Input
#
# None <- 1 <-> 2 <-> 3 <-> 4 -> None
#
# Expected Output
#
# 4 -> 3 -> 2 -> 1 -> None
#
# Hint
# Find last node then move using prev.
#
# 3️⃣ Insert at Beginning
#
# Input
#
# 1 <-> 2 <-> 3
#
# Insert 0
#
# Expected Output
#
# 0 <-> 1 <-> 2 <-> 3
# 4️⃣ Insert at End
#
# Input
#
# 1 <-> 2 <-> 3
#
# Insert 4
#
# Expected Output
#
# 1 <-> 2 <-> 3 <-> 4
# 5️⃣ Insert at Position
#
# Input
#
# 1 <-> 2 <-> 4 <-> 5
#
# Insert 3 at position 3
#
# Expected Output
#
# 1 <-> 2 <-> 3 <-> 4 <-> 5
# 6️⃣ Delete First Node
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4
#
# Expected Output
#
# 2 <-> 3 <-> 4
# 7️⃣ Delete Last Node
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4
#
# Expected Output
#
# 1 <-> 2 <-> 3
# 8️⃣ Delete Node by Value
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4
#
# Delete 3
#
# Expected Output
#
# 1 <-> 2 <-> 4
# 9️⃣ Count Nodes
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4
#
# Expected Output
#
# 4
# 🔟 Search Element
#
# Input
#
# 1 <-> 3 <-> 5 <-> 7
#
# Search 5
#
# Output
#
# Found
# 1️⃣1️⃣ Reverse Doubly Linked List
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4
#
# Expected Output
#
# 4 <-> 3 <-> 2 <-> 1
#
# Hint
#
# Swap
#
# prev <-> next
# 1️⃣2️⃣ Find Middle Node
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4 <-> 5
#
# Output
#
# 3
#
# Use slow and fast pointer.
#
# 1️⃣3️⃣ Remove Duplicates (Sorted DLL)
#
# Input
#
# 1 <-> 1 <-> 2 <-> 3 <-> 3
#
# Output
#
# 1 <-> 2 <-> 3
# 1️⃣4️⃣ Pair Sum Problem (Important)
#
# Input
#
# 1 <-> 2 <-> 3 <-> 4 <-> 5
#
# Target = 6
#
# Output
#
# (1,5)
# (2,4)
#
# Use two pointer technique.
#
# ⭐ Most Important Doubly Linked List Interview Questions
#
# Reverse DLL
#
# Insert at position
#
# Delete node
#
# Find pair with given sum
#
# Rotate DLL
#
# Flatten DLL
#
# LRU Cache (DLL + HashMap)
